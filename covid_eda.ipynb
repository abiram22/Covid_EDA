# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
with open('C:/Users/abi/Desktop/json') as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data["records"])

# %%
df.tail(5)
# Out:
#           dateRep day month  year  cases  deaths countriesAndTerritories  \
# 61895  25/03/2020  25    03  2020      0       0                Zimbabwe
# 61896  24/03/2020  24    03  2020      0       1                Zimbabwe
# 61897  23/03/2020  23    03  2020      0       0                Zimbabwe
# 61898  22/03/2020  22    03  2020      1       0                Zimbabwe
# 61899  21/03/2020  21    03  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 61895    ZW                  ZWE   14645473.0       Africa
# 61896    ZW                  ZWE   14645473.0       Africa
# 61897    ZW                  ZWE   14645473.0       Africa
# 61898    ZW                  ZWE   14645473.0       Africa
# 61899    ZW                  ZWE   14645473.0       Africa
#
#       Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 61895
# 61896
# 61897
# 61898
# 61899

# %%
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %%
df.columns.size
# Out:
# 12

# %%
df.shape
# Out:
# (61900, 12)

# %%
df.isnull().sum()
# Out:
# dateRep                                                         0
# day                                                             0
# month                                                           0
# year                                                            0
# cases                                                           0
# deaths                                                          0
# countriesAndTerritories                                         0
# geoId                                                           0
# countryterritoryCode                                          123
# popData2019                                                   123
# continentExp                                                    0
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000      0
# dtype: int64

# %%
df.countriesAndTerritories.unique().size
# Out:
# 214

# %%
df.drop(['day', 'month', 'year'], axis=1, inplace = True)

# %%
df.isnull().value_counts()
# Out:
# dateRep  cases  deaths  countriesAndTerritories  geoId  countryterritoryCode  popData2019  continentExp  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# False    False  False   False                    False  False                 False        False         False                                                         61777
#                                                         True                  True         False         False                                                           123
# dtype: int64

# %%
df.rename(columns = {'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': '14_day_cases'}, inplace = True)

# %%
df.isnull().value_counts()
# Out:
# dateRep  cases  deaths  countriesAndTerritories  geoId  countryterritoryCode  popData2019  continentExp  14_day_cases
# False    False  False   False                    False  False                 False        False         False           61777
#                                                         True                  True         False         False             123
# dtype: int64

# %%
df.dropna(inplace= True)

# %%
df.shape
# Out:
# (61777, 9)

# %%
df.isnull().sum()
# Out:
# dateRep                    0
# cases                      0
# deaths                     0
# countriesAndTerritories    0
# geoId                      0
# countryterritoryCode       0
# popData2019                0
# continentExp               0
# 14_day_cases               0
# dtype: int64

# %%
df.head()
# Out:
#       dateRep  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020    746       6             Afghanistan    AF
# 1  13/12/2020    298       9             Afghanistan    AF
# 2  12/12/2020    113      11             Afghanistan    AF
# 3  11/12/2020     63      10             Afghanistan    AF
# 4  10/12/2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp 14_day_cases
# 0                  AFG   38041757.0         Asia   9.01377925
# 1                  AFG   38041757.0         Asia   7.05277624
# 2                  AFG   38041757.0         Asia   6.86876792
# 3                  AFG   38041757.0         Asia   7.13426564
# 4                  AFG   38041757.0         Asia   6.96865815

# %%
 df[df['14_day_cases'] == '']
# Out:
#           dateRep  cases  deaths countriesAndTerritories geoId  \
# 327    12/01/2020      0       0             Afghanistan    AF
# 328    11/01/2020      0       0             Afghanistan    AF
# 329    10/01/2020      0       0             Afghanistan    AF
# 330    09/01/2020      0       0             Afghanistan    AF
# 331    08/01/2020      0       0             Afghanistan    AF
# ...           ...    ...     ...                     ...   ...
# 61895  25/03/2020      0       0                Zimbabwe    ZW
# 61896  24/03/2020      0       1                Zimbabwe    ZW
# 61897  23/03/2020      0       0                Zimbabwe    ZW
# 61898  22/03/2020      1       0                Zimbabwe    ZW
# 61899  21/03/2020      1       0                Zimbabwe    ZW
#
#       countryterritoryCode  popData2019 continentExp 14_day_cases
# 327                    AFG   38041757.0         Asia
# 328                    AFG   38041757.0         Asia
# ...

# %%
df['14_day_cases'].replace('', 0, inplace = True)

# %%
df
# Out:
#           dateRep  cases  deaths countriesAndTerritories geoId  \
# 0      14/12/2020    746       6             Afghanistan    AF
# 1      13/12/2020    298       9             Afghanistan    AF
# 2      12/12/2020    113      11             Afghanistan    AF
# 3      11/12/2020     63      10             Afghanistan    AF
# 4      10/12/2020    202      16             Afghanistan    AF
# ...           ...    ...     ...                     ...   ...
# 61895  25/03/2020      0       0                Zimbabwe    ZW
# 61896  24/03/2020      0       1                Zimbabwe    ZW
# 61897  23/03/2020      0       0                Zimbabwe    ZW
# 61898  22/03/2020      1       0                Zimbabwe    ZW
# 61899  21/03/2020      1       0                Zimbabwe    ZW
#
#       countryterritoryCode  popData2019 continentExp 14_day_cases
# 0                      AFG   38041757.0         Asia   9.01377925
# 1                      AFG   38041757.0         Asia   7.05277624
# ...

# %%
df.reset_index(inplace = True, drop = True)

# %%
df
# Out:
#           dateRep  cases  deaths countriesAndTerritories geoId  \
# 0      14/12/2020    746       6             Afghanistan    AF
# 1      13/12/2020    298       9             Afghanistan    AF
# 2      12/12/2020    113      11             Afghanistan    AF
# 3      11/12/2020     63      10             Afghanistan    AF
# 4      10/12/2020    202      16             Afghanistan    AF
# ...           ...    ...     ...                     ...   ...
# 61772  25/03/2020      0       0                Zimbabwe    ZW
# 61773  24/03/2020      0       1                Zimbabwe    ZW
# 61774  23/03/2020      0       0                Zimbabwe    ZW
# 61775  22/03/2020      1       0                Zimbabwe    ZW
# 61776  21/03/2020      1       0                Zimbabwe    ZW
#
#       countryterritoryCode  popData2019 continentExp 14_day_cases
# 0                      AFG   38041757.0         Asia   9.01377925
# 1                      AFG   38041757.0         Asia   7.05277624
# ...

# %%
df.dateRep = pd.to_datetime(df['dateRep'])

# %%
type(df.dateRep[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.sort_values(by=['dateRep'])
# Out:
#          dateRep  cases  deaths countriesAndTerritories geoId  \
# 8340  2019-12-31      0       0                  Brazil    BR
# 43246 2019-12-31      0       0                    Oman    OM
# 17434 2019-12-31      0       0                   Egypt    EG
# 54594 2019-12-31      0       0             Switzerland    CH
# 15237 2019-12-31      0       0                 Czechia    CZ
# ...          ...    ...     ...                     ...   ...
# 33112 2020-12-14      0       0                 Liberia    LR
# 60988 2020-12-14      0       0                   Yemen    YE
# 54862 2020-12-14      4       0                  Taiwan    TW
# 34613 2020-12-14      0       0              Madagascar    MG
# 0     2020-12-14    746       6             Afghanistan    AF
#
#       countryterritoryCode  popData2019 continentExp 14_day_cases
# 8340                   BRA  211049519.0      America            0
# 43246                  OMN    4974992.0         Asia            0
# ...

# %%
df.reset_index(inplace = True, drop= True)

# %%
df.to_csv('Desktop/covid.csv')
